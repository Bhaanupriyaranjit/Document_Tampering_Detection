# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhaanupriyaranjit/Document_Tampering_Detection/blob/main/Task1_DataBrick_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import zipfile
from google.colab import files

# 1. Upload the kaggle.json file you just downloaded
print("Please upload your kaggle.json file when prompted:")
uploaded = files.upload()

# 2. Configure Kaggle credentials in Colab environment
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# 3. Download the DocTamper dataset directly from Kaggle in seconds!
# Replace 'username/dataset-slug' with the exact Kaggle dataset handle
# !kaggle datasets download -d <kaggle-dataset-slug-here>

# 4. Unzip dataset in Colab storage
# !unzip -q *.zip -d ./DocTamperData
print("✅ Dataset downloaded and extracted successfully!")

# %%
import os
import shutil
from PIL import Image

# Create your 3 class directories in Colab
os.makedirs("Data_Brick/Class1_Receipts", exist_ok=True)
os.makedirs("Data_Brick/Class2_Invoices", exist_ok=True)
os.makedirs("Data_Brick/Class3_Forms_Contracts", exist_ok=True)

# Path where your images are located after extraction
source_folder = "./DocTamperData"

# Code to list and view image paths
images = [os.path.join(dp, f) for dp, dn, filenames in os.walk(source_folder)
          for f in filenames if f.endswith(('.png', '.jpg', '.jpeg'))]

print(f"Total images available: {len(images)}")
